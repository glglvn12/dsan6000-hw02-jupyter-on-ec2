# %%
# %%bash
# aws s3 mb s3://dsan6000-yk816
# aws s3 cp data/ s3://dsan6000-yk816/wikipedia-hourly/ --recursive
# aws s3 ls s3://dsan6000-yk816/wikipedia-hourly/
# aws s3 mb makes a private bucket by default.
# Out:
# make_bucket: dsan6000-yk816
# upload: data/20260901_050000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_050000.parquet
# upload: data/20260901_040000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_040000.parquet
# upload: data/20260901_140000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_140000.parquet
# upload: data/20260901_150000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_150000.parquet
# upload: data/20260901_060000.parquet to s3://dsan6000-yk816/wikipe MiB/s) with 20 file(s) remainingdia-hourly/20260901_060000.parquet
# upload: data/20260901_070000.par9 MiB/s) with 19 file(s) remaining MiB/s) with 19 file(s) remainingquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_070000.parquet
# upload: data/20260901_110000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_110000.parquet
# upload: data/20260901_100000.parquet to s3://dsan6000-yk816/wikipedia-hourly/20260901_100000.parquet
# ...
