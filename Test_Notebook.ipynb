# %%
1 + 1
# Out:
# 2

# %%
# !pwd
# Out:
# /home/ubuntu/dsan6000-hw02-jupyter-on-ec2

# %%
# !ls -al
# Out:
# total 456
# drwxrwxr-x  6 ubuntu ubuntu   4096 Sep 18 15:33 .
# drwxr-x--- 13 ubuntu ubuntu   4096 Sep 18 15:25 ..
# drwxrwxr-x  7 ubuntu ubuntu   4096 Sep 18 15:45 .git
# -rw-rw-r--  1 ubuntu ubuntu     39 Sep 18 15:44 .gitignore
# -rw-rw-r--  1 ubuntu ubuntu      5 Sep 18 14:57 .python-version
# drwxrwxr-x  5 ubuntu ubuntu   4096 Sep 18 14:58 .venv
# -rw-rw-r--  1 ubuntu ubuntu  19591 Sep 18 14:57 README.md
# -rw-rw-r--  1 ubuntu ubuntu    796 Sep 18 14:57 Test_Notebook.ipynb
# drwxrwxr-x  2 ubuntu ubuntu   4096 Sep 18 15:41 data
# -rw-rw-r--  1 ubuntu ubuntu   6041 Sep 18 15:32 hw02-1-download-data.ipynb
# -rw-rw-r--  1 ubuntu ubuntu   7384 Sep 18 15:41 hw02-2-date-lake.ipynb
# -rw-rw-r--  1 ubuntu ubuntu 177735 Sep 18 15:48 hw02-3-hourly-plots.ipynb
# drwxrwxr-x  2 ubuntu ubuntu   4096 Sep 18 15:40 images
# -rw-rw-r--  1 ubuntu ubuntu    106 Sep 18 14:57 main.py
# -rw-rw-r--  1 ubuntu ubuntu    299 Sep 18 14:57 pyproject.toml
# ...
