# %%
# %%bash
# cd ~/dsan6000-hw02-jupyter-on-ec2
# export NETID=yk816

# %%
# %%bash
# aws s3 cp s3://dsan6000-wikipedia/hourly_parquet/ data/ --recursive
# ls data | wc -l
# du -sh data
# Out:
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_050000.parquet to data/20260901_050000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_100000.parquet to data/20260901_100000.par  quet
# download: s3://dsan6000-wikipedia/iB/s) with 22 file(s) remainingiB/s) with 22 file(s) remaininghourly_parquet/20260901_090000.parquet to data/20260901_090000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_120000.parquet to data/20260901_120000.par) with 21 file(s) remainingmpleted 5.3 MiB/30.5 MiB (15.7 MiB/s) with 21 file(s) remaining/s) with 21 file(s) remainingleted 6.1 MiB/30.5 MiB (17.7 MiB/s) with 21 file(s) remainingiB/s) with 21 file(s) remainingmpleted 7.1 MiB/30.5 MiB (20.2 MiB/s) with 21 file(s) remaining/s) with 21 file(s) remainingquet
# ...
