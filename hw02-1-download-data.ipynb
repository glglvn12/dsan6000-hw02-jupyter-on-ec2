# %%
# %%bash
# cd ~/dsan6000-hw02-jupyter-on-ec2
# export NETID=yk816

# %%
# %%bash
# aws s3 cp s3://dsan6000-wikipedia/hourly_parquet/ data/ --recursive
# ls data | wc -l
# du -sh data
# Out:
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_040000.parquet to data/20260901_040000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_060000.parquet to data/20260901_060000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_110000.parwith 22 file(s) remainingiB/s) with 22 file(s) remainingmpleted 3.8 MiB/30.5 MiB (12.9 MiB/s) with 22 file(s) remainingiB/s) with 22 file(s) remainingiB/s) with 22 file(s) remainingiB/s) with 22 file(s) remainingiB/s) with 22 file(s) remainingquet to data/20260901_110000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_070000.parquet to data/20260901_070000.parted 7.4 MiB/30.5 MiB (21.9 MiB/s) with 21 file(s) remaining/s) with 21 file(s) remainingquet
# download: s3://dsan6000-wikip3.5 MiB/s) with 20 file(s) remainingedia/hourly_parquet/20260901_080000.parquet to data/20260901_080000.parquet
# ...
